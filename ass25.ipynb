# %% [raw]
# #Q1.
#
# Seaborn is a popular Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating informative and attractive statistical graphics. Here are five common plots that you can create using Seaborn, along with their uses:
#
#     1.Scatter Plot:
#         Use: Scatter plots are used to visualize the relationship between two continuous variables. Each point on the plot represents an observation with values for both variables, allowing you to assess patterns, trends, and correlations.
#         Function: seaborn.scatterplot()
#
#     2.Line Plot:
#         Use: Line plots are useful for visualizing the trend or progression of a single variable over time or another continuous dimension. They are often used for time series data or to show the evolution of a variable.
#         Function: seaborn.lineplot()
#
#     3.Bar Plot:
#         Use: Bar plots are used to compare categorical data by displaying the frequency or values of each category as bars. They are great for showing comparisons and distributions of discrete data.
#         Function: seaborn.barplot() or seaborn.countplot() (for counting categorical occurrences)
#
#     4.Histogram:
#         Use: Histograms are used to visualize the distribution of a single variable. They group data into bins and display the frequency or density of observations within each bin. Histograms help you understand the underlying data distribution.
#         Function: seaborn.histplot() or seaborn.distplot() (for more advanced features)
#
#     5.Box Plot:
#         Use: Box plots (box-and-whisker plots) are effective for displaying the summary statistics of a dataset's distribution, including median, quartiles, and potential outliers. They help in identifying the central tendency and spread of the data.
#         Function: seaborn.boxplot()
#
# These are just a few examples of the types of plots you can create using Seaborn. The library provides a wide range of customization options to tailor your visualizations according to your needs, and it works seamlessly with Pandas DataFrames, making it a powerful tool for exploratory data analysis and presentation of insights

# %%
#Q2.

import seaborn as sns

fmri = sns.load_dataset("fmri")

sns.lineplot( x = "timepoint",
             y = "signal",
             data = fmri);

# %%
#Q3.

import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

plt.figure(figsize=(10, 6))

sns.boxplot(x="pclass", y="age", data=df)
plt.title("Box Plot of Age by Passenger Class")
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x="pclass", y="fare", data=df)
plt.title("Box Plot of Fare by Passenger Class")
plt.show()

# %%
#Q4.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the diamonds dataset from Seaborn
diamonds = sns.load_dataset('diamonds')

# Create a histogram with 'price' column and 'cut' column as hue
sns.histplot(data=diamonds, x='price', hue='cut', multiple='stack', bins=30)

# Set plot labels and title
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Diamond Prices by Cut')

# Display the plot
plt.show()

# %%
#Q5.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the iris dataset
iris = sns.load_dataset("iris")

# Create a pair plot with hue parameter
sns.pairplot(iris, hue="species")

# Display the plot
plt.show()

# %%
#Q6.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
flights = sns.load_dataset("flights")

# Pivot the data to create a matrix suitable for a heatmap
flights_pivot = flights.pivot_table(index="month", columns="year", values="passengers")

# Create a heatmap using Seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(flights_pivot, cmap="YlGnBu", annot=True, fmt="d", linewidths=0.5)

# Customize the plot
plt.title("Flights Heatmap")
plt.xlabel("Year")
plt.ylabel("Month")

# Show the plot
plt.show()
